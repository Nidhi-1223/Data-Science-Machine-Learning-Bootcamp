# %%
import pandas as pd

# %%
colors = pd.Series(["black", "white", "blue"])

# %%
colors
# Out:
# 0    black
# 1    white
# 2     blue
# dtype: object

# %%
cars = pd.Series(["BMW", "Audi", "Mercedes"])

# %%
cars
# Out:
# 0         BMW
# 1        Audi
# 2    Mercedes
# dtype: object

# %%
Car_data = pd.DataFrame({"Cars" : cars, "Colors" : colors})

# %%
Car_data
# Out:
#        Cars Colors
# 0       BMW  black
# 1      Audi  white
# 2  Mercedes   blue

# %%
csvFile_car_sales = "/home/hp1/Documents/College/Coding/Machine Learning/zero_to_mastery_course/Pandas Library/car-sales.csv"

# %%
car_sales_dataframe = pd.read_csv(csvFile_car_sales)

# %%
car_sales_dataframe
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
Car_data.to_csv("Car_data_csv_for_exercise.csv", index = False)

# %%
pd.read_csv("Car_data_csv_for_exercise.csv")
# Out:
#        Cars Colors
# 0       BMW  black
# 1      Audi  white
# 2  Mercedes   blue

# %%
Car_data.dtypes
# Out:
# Cars      object
# Colors    object
# dtype: object

# %%
Car_data.describe()
# Out:
#        Cars Colors
# count     3      3
# unique    3      3
# top     BMW  black
# freq      1      1

# %%
Car_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Cars    3 non-null      object
#  1   Colors  3 non-null      object
# dtypes: object(2)
# memory usage: 176.0+ bytes

# %%
numbers = pd.Series([45,521,656,2,23])
numbers
# Out:
# 0     45
# 1    521
# 2    656
# 3      2
# 4     23
# dtype: int64

# %%
numbers.describe()
# Out:
# count      5.000000
# mean     249.400000
# std      313.581409
# min        2.000000
# 25%       23.000000
# 50%       45.000000
# 75%      521.000000
# max      656.000000
# dtype: float64

# %%
numbers.sum()
# Out:
# 1247

# %%
numbers.mean()
# Out:
# 249.4

# %%
car_sales_dataframe.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
len(car_sales_dataframe)
# Out:
# 10

# %%
car_sales_dataframe.head(7)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00

# %%
car_sales_dataframe.tail(7)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales_dataframe.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
car_sales_dataframe.iloc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
car_sales_dataframe["Odometer (KM)"]
# Out:
# 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Odometer (KM), dtype: int64

# %%
car_sales_dataframe[car_sales_dataframe["Odometer (KM)" ] > 100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
pd.crosstab(car_sales_dataframe["Make"], car_sales_dataframe["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
car_sales_dataframe.groupby(["Make"]).mean()
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
car_sales_dataframe["Odometer (KM)"].hist()
# Out:
# <AxesSubplot:>

# %%
car_sales_dataframe["Price"] = car_sales_dataframe["Price"].str.replace('[\$\,]','',regex= True).astype(float)

# %%
car_sales_dataframe["Price"].plot()
# Out:
# <AxesSubplot:>

# %%
csvFile_missing_data = "/home/hp1/Documents/College/Coding/Machine Learning/zero_to_mastery_course/Pandas Library/car-sales-missing-data.csv"

# %%
missing_data_dataframe = pd.read_csv(csvFile_missing_data)

# %%
missing_data_dataframe
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
missing_data_dataframe["Odometer"].fillna(missing_data_dataframe["Odometer"].mean(), inplace=True)
missing_data_dataframe
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
missing_data_dropped = missing_data_dataframe.dropna()
missing_data_dropped
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
missing_data_dropped.to_csv('missing_data_dropped.csv')

# %%
car_sales_dataframe
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   4000.0
# 1   Honda    Red          87899      4   5000.0
# 2  Toyota   Blue          32549      3   7000.0
# 3     BMW  Black          11179      5  22000.0
# 4  Nissan  White         213095      4   3500.0
# 5  Toyota  Green          99213      4   4500.0
# 6   Honda   Blue          45698      4   7500.0
# 7   Honda   Blue          54738      4   7000.0
# 8  Toyota  White          60000      4   6250.0
# 9  Nissan  White          31600      4   9700.0

# %%
seats_column = pd.Series([5,5,5])

# %%
car_sales_dataframe["seats"] = seats_column
car_sales_dataframe
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  seats
# 0  Toyota  White         150043      4   4000.0    5.0
# 1   Honda    Red          87899      4   5000.0    5.0
# 2  Toyota   Blue          32549      3   7000.0    5.0
# 3     BMW  Black          11179      5  22000.0    NaN
# 4  Nissan  White         213095      4   3500.0    NaN
# 5  Toyota  Green          99213      4   4500.0    NaN
# 6   Honda   Blue          45698      4   7500.0    NaN
# 7   Honda   Blue          54738      4   7000.0    NaN
# 8  Toyota  White          60000      4   6250.0    NaN
# 9  Nissan  White          31600      4   9700.0    NaN

# %%
car_sales_dataframe.fillna(car_sales_dataframe["seats"].mean(),inplace= True)
car_sales_dataframe
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  seats
# 0  Toyota  White         150043      4   4000.0    5.0
# 1   Honda    Red          87899      4   5000.0    5.0
# 2  Toyota   Blue          32549      3   7000.0    5.0
# 3     BMW  Black          11179      5  22000.0    5.0
# 4  Nissan  White         213095      4   3500.0    5.0
# 5  Toyota  Green          99213      4   4500.0    5.0
# 6   Honda   Blue          45698      4   7500.0    5.0
# 7   Honda   Blue          54738      4   7000.0    5.0
# 8  Toyota  White          60000      4   6250.0    5.0
# 9  Nissan  White          31600      4   9700.0    5.0

# %%
engine_size_column = pd.Series([1.3,2.6,3.9,4.0])

# %%
car_sales_dataframe["engine size"] = engine_size_column

# %%
car_sales_dataframe
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  seats  engine size
# 0  Toyota  White         150043      4   4000.0    5.0          1.3
# 1   Honda    Red          87899      4   5000.0    5.0          2.6
# 2  Toyota   Blue          32549      3   7000.0    5.0          3.9
# 3     BMW  Black          11179      5  22000.0    5.0          4.0
# 4  Nissan  White         213095      4   3500.0    5.0          NaN
# 5  Toyota  Green          99213      4   4500.0    5.0          NaN
# 6   Honda   Blue          45698      4   7500.0    5.0          NaN
# 7   Honda   Blue          54738      4   7000.0    5.0          NaN
# 8  Toyota  White          60000      4   6250.0    5.0          NaN
# 9  Nissan  White          31600      4   9700.0    5.0          NaN

# %%
car_sales_dataframe.fillna(car_sales_dataframe["engine size"].mean(),inplace= True)
car_sales_dataframe
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  seats  engine size
# 0  Toyota  White         150043      4   4000.0    5.0         1.30
# 1   Honda    Red          87899      4   5000.0    5.0         2.60
# 2  Toyota   Blue          32549      3   7000.0    5.0         3.90
# 3     BMW  Black          11179      5  22000.0    5.0         4.00
# 4  Nissan  White         213095      4   3500.0    5.0         2.95
# 5  Toyota  Green          99213      4   4500.0    5.0         2.95
# 6   Honda   Blue          45698      4   7500.0    5.0         2.95
# 7   Honda   Blue          54738      4   7000.0    5.0         2.95
# 8  Toyota  White          60000      4   6250.0    5.0         2.95
# 9  Nissan  White          31600      4   9700.0    5.0         2.95

# %%
car_sales_dataframe_shuffled= car_sales_dataframe.sample(frac=1)
car_sales_dataframe_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  seats  engine size
# 7   Honda   Blue          54738      4   7000.0    5.0         2.95
# 3     BMW  Black          11179      5  22000.0    5.0         4.00
# 0  Toyota  White         150043      4   4000.0    5.0         1.30
# 6   Honda   Blue          45698      4   7500.0    5.0         2.95
# 2  Toyota   Blue          32549      3   7000.0    5.0         3.90
# 5  Toyota  Green          99213      4   4500.0    5.0         2.95
# 8  Toyota  White          60000      4   6250.0    5.0         2.95
# 4  Nissan  White         213095      4   3500.0    5.0         2.95
# 9  Nissan  White          31600      4   9700.0    5.0         2.95
# 1   Honda    Red          87899      4   5000.0    5.0         2.60

# %%
car_sales_dataframe_shuffled.reset_index(drop=True,inplace=True)

# %%
car_sales_dataframe_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  seats  engine size
# 0   Honda   Blue          54738      4   7000.0    5.0         2.95
# 1     BMW  Black          11179      5  22000.0    5.0         4.00
# 2  Toyota  White         150043      4   4000.0    5.0         1.30
# 3   Honda   Blue          45698      4   7500.0    5.0         2.95
# 4  Toyota   Blue          32549      3   7000.0    5.0         3.90
# 5  Toyota  Green          99213      4   4500.0    5.0         2.95
# 6  Toyota  White          60000      4   6250.0    5.0         2.95
# 7  Nissan  White         213095      4   3500.0    5.0         2.95
# 8  Nissan  White          31600      4   9700.0    5.0         2.95
# 9   Honda    Red          87899      4   5000.0    5.0         2.60

# %%
car_sales_dataframe["Odometer(Miles)"] = car_sales_dataframe["Odometer (KM)"].apply(lambda x:x/1.6)
car_sales_dataframe
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  seats  engine size  \
# 0  Toyota  White         150043      4   4000.0    5.0         1.30
# 1   Honda    Red          87899      4   5000.0    5.0         2.60
# 2  Toyota   Blue          32549      3   7000.0    5.0         3.90
# 3     BMW  Black          11179      5  22000.0    5.0         4.00
# 4  Nissan  White         213095      4   3500.0    5.0         2.95
# 5  Toyota  Green          99213      4   4500.0    5.0         2.95
# 6   Honda   Blue          45698      4   7500.0    5.0         2.95
# 7   Honda   Blue          54738      4   7000.0    5.0         2.95
# 8  Toyota  White          60000      4   6250.0    5.0         2.95
# 9  Nissan  White          31600      4   9700.0    5.0         2.95
#
#    Odometer(Miles)
# 0        93776.875
# 1        54936.875
# 2        20343.125
# 3         6986.875
# 4       133184.375
# 5        62008.125
# 6        28561.250
# 7        34211.250
# 8        37500.000
# ...
